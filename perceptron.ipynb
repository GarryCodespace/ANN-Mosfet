# %% [markdown]
# <a href="https://colab.research.google.com/github/GarryCodespace/ANN-Mosfet/blob/main/perceptron.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Predict body shape

# %% [markdown]
# ## Prepare Data

# %% [markdown]
# The raw data is a NumPy array where each row represents a person. The columns are `height_cm`, `weight_kg`, and `label`. The `label` is 0 for 'not overweight' and 1 for 'overweight'.

# %%
import numpy as np
import matplotlib.pyplot as plt

raw_data = np.array([
    # height_cm, weight_kg, label
    [175, 71, 0],
    [160, 63, 0],
    [180, 92, 1],
    [168, 82, 1],
    [155, 50, 0],
    [172, 68, 0],
    [165, 76, 1],
    [190, 96, 1],
    [158, 58, 0],
    [182, 78, 0],
    [170, 88, 1],
    [177, 85, 1],
    [162, 54, 0],
    [185, 74, 0],
    [173, 95, 1],
    [169, 64, 0],
    [181, 89, 1],
    [157, 70, 1],
    [176, 72, 0],
    [164, 61, 0],
])

features = raw_data[:, :2]
labels = raw_data[:, 2]

print("== Raw Data ==")
for height, weight, label in raw_data:
    print(f"Height: {height}, Weight: {weight}, Label: {label}")
# Out:
# == Raw Data ==
# Height: 175, Weight: 71, Label: 0
# Height: 160, Weight: 63, Label: 0
# Height: 180, Weight: 92, Label: 1
# Height: 168, Weight: 82, Label: 1
# Height: 155, Weight: 50, Label: 0
# Height: 172, Weight: 68, Label: 0
# Height: 165, Weight: 76, Label: 1
# Height: 190, Weight: 96, Label: 1
# Height: 158, Weight: 58, Label: 0
# Height: 182, Weight: 78, Label: 0
# Height: 170, Weight: 88, Label: 1
# Height: 177, Weight: 85, Label: 1
# Height: 162, Weight: 54, Label: 0
# Height: 185, Weight: 74, Label: 0
# Height: 173, Weight: 95, Label: 1
# Height: 169, Weight: 64, Label: 0
# Height: 181, Weight: 89, Label: 1
# Height: 157, Weight: 70, Label: 1
# Height: 176, Weight: 72, Label: 0
# Height: 164, Weight: 61, Label: 0
